# %%
# !pip install langchain langchain-groq langchain-community langchain-core --quiet

# %%
import os
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

os.environ["GROQ_API_KEY"]=""

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

prompt = PromptTemplate(
    input_variables=["instruction"],
    template="""
Follow the instruction and provide the output clearly.

Instruction: {instruction}
"""
)

parser=StrOutputParser()

chain= prompt | llm | parser

response= chain.invoke(
    {"instruction":"Translate ''to tamil"}
)

print("Zero Shot Output: ",response)
# Out:
# Zero Shot Output:  The translation of "Go to hell" in Tamil is:
#
#
# நரகத்துக்குப் போ (Narakattukku pō)
#
#
# Note: Please be aware that this phrase is considered profane and should be used with caution.
