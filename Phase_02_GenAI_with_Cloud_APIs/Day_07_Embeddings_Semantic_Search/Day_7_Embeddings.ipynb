# %%
# !pip install chromadb sentence-transformers -q
print("Installation completed")
# Out:
# Installation completed

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb
print("All libraries imported successfully!")
print(f"ChromaDB version: {chromadb.__version__}")
# Out:
# All libraries imported successfully!
# ChromaDB version: 1.5.9

# %%
documents = [
    "ETL is used to clean the data",
    "Everybody drives a car",
    "Usage of public transport like bus and train has been decreased",
    "The community for bikes has been started lately",
    "Everyone in the country started using cycles"
]

query_keyword = "transport"

print(f"KEYWORD SEARCH for: '{query_keyword}'\n")

for i, doc in enumerate(documents):
    if query_keyword.lower() in doc.lower():
        print(f"FOUND  [doc_{i}]: {doc}")
    else:
        print(f"MISSED [doc_{i}]: {doc}")
# Out:
# KEYWORD SEARCH for: 'transport'
#
# MISSED [doc_0]: ETL is used to clean the data
# MISSED [doc_1]: Everybody drives a car
# FOUND  [doc_2]: Usage of public transport like bus and train has been decreased
# MISSED [doc_3]: The community for bikes has been started lately
# MISSED [doc_4]: Everyone in the country started using cycles

# %%
# !pip install llama-index llama-index-llms-groq sentence-transformers --q

# %%
# !pip install llama-index-embeddings-huggingface --q

# %%
import os
from textwrap import dedent

os.makedirs("data",exist_ok=True)
file_path="data/AIDS_Department.txt"
content=dedent("""

SRI ESHWAR ENGINEERING COLLEGE (SECE)
ARTIFICIAL INTELLIGENCE & DATA SCIENCE DEPARTMENT

44 LPA HIGHEST SALARY PACKAGE
120+ RECRUITERS
30+ PUBLICATIONS
10+ PATENTS

PROGRAMME SCOPE
The biggest ever technological advancement this century has witnessed is making machines think and act like humans using Artificial Intelligence powered by Data. AI-driven systems are becoming dominant in every aspect of life. Autonomous Vehicles, Virtual Assistants (Alexa, Siri), and Domestic Assistants are examples. AI & DS is emerging as a promising field for engineers interested in data and visualization.

LEARNING SCOPE
Students will be able to design, develop, and apply AI and DS solutions to real-world business challenges. Technologies covered include:
- Deep Learning
- Computer Vision
- Data Science
- Predictive Analytics
- AR/VR
- Natural Language Processing
- Robotics
- Software Technologies
- OOP
- Database Management Systems

CAREER PROGRESSION
Employment opportunities include:
- Data Scientist
- Data Analyst
- Machine Learning Architect
- Software Developer
Industries include Healthcare, Travel & Transportation, and FMCG.

VISION
To build a conducive academic and research environment in Artificial Intelligence and Data Science enabling global education, research, and entrepreneurship.

MISSION
1. Update curriculum with global trends and technological advancements.
2. Promote research through state-of-the-art infrastructure.
3. Empower faculty through upskilling and international collaborations.
4. Encourage innovation and entrepreneurship for solving societal challenges.

LABS
- Programming Languages Laboratory
- Full Stack Development Laboratory
- Artificial Intelligence Laboratory
- Data Science Laboratory
- Data Visualization & Exploration Laboratory
- Machine Learning Laboratory
- Computer Vision Laboratory
- Natural Language Programming Laboratory

CENTRES OF EXCELLENCE
- CoE in Data Science
- CoE in AI and Robotics

VALUE ADDED COURSES
- Mastering OpenCV
- Application Development using KNIME
- Mastering TensorFlow and Keras
- Apache Spark and Databricks
- Application Development using Golang
- Prompt Engineering

HEAD OF DEPARTMENT
Dr. G. Sathish Kumar
Associate Professor & HOD

FACULTY MEMBERS
Dr. L. Raja
Dr. K. Mohaideen Abdul Kadhar
Dr. S. Sheeba Rani Gnanamalar
Dr. M. Mohammed Mustafa
Dr. G. Shobana
Dr. A. Sivaramakrishnan
Dr. M. P. Geetha
Dr. M. Thenmozhi
Dr. M. Nivaashini
Dr. P. Dinesh Kumar
Dr. T. Kanimozhi
Dr. L. R. Sujithra
Dr. C. Rajeshkumar
Ms. P. Chitra
Ms. S. Gowri
Ms. E. Anitha
Ms. S. Rajalakshmi
Ms. K. Parvathy
Ms. M. Sowmiya
Ms. S. Sowmiya
Mr. S. Sridharan
Ms. A. Soundarya
Ms. V. Sangavi
Ms. R. Geetha Rajakumari
Mr. R. Divakar
Ms. G. Durga Devi
Ms. N. Pooranam
Mr. S. Sam Peter
Ms. K. Parimalam
Ms. C. Saranya
Ms. D. Hema Malini
Ms. P. Anusha Devi
Ms. S. V. Uma
Mr. Alaksandar Jesus Gene

STUDENT ACHIEVEMENTS
- VOID.V1 Hackathon 2025 – Sakthivel M (III AI&DS) – 4th Place
- Rolls Royce R2 Data Labs Responsible Hackathon – Winner
- Harvard Project for International Relations – Top 200 Participant
- Plastic Free AI Hackathon – Top 15 Finalist
- TANCAM'S TNWISE – 4th Place
- Codethon – Winners
- Adobe Student Ambassadors – Top 80 in India
- SMARTX Hackathon 2025 – 2nd Place

EVENTS
- Evolution of Gen AI on Cloud Platform
- Future Engineering Demystified: Transforming Data with Python
- Drafting a Research Article
- Mastering Data Science Basics
- Beyond Intelligence: Shaping the Future
- Transforming Tomorrow: The Age of AI and Robotics
- Data Science Boot Camp
- Mastering the Data Universe
- Data Expedition
- OBE Awareness and Attainment Process
- Next Gen C++ Innovation through STL, Concurrency & Beyond
- Node.js & GraphQL
- ROS Beginner and Intermediate Course
- Conclave 2024
- AI for Future Workforce
- Exploring the Future of Machine Learning and Data Structure
- Cloud Computing Mastery
- Data Science in Action

RESEARCH
The department encourages research through funding support from DST, AICTE, TNSCCT, MHRD, CSIR, DRDO, ISTE and industry collaborations. Facilities include:
- AU Approved Research Supervisors
- Research Facilities
- Publications
- Patents
- Research Grants & Seed Funds
- Consultancy Projects

INDUSTRY COLLABORATION
Activities include:
- MoUs
- Industry Visits
- Internships
- CoE Activities
- Projects

AI&DS OFFICE
Dr. M. Mohammed Mustafa
Associate Professor & HoD, AIDS
Phone: +91 4259 200452
Email: hodaids@sece.ac.in

Ms. P. Brindha
Department Office Secretary
Phone: +91 4259 200454
Email: aids_support@sece.ac.in

COLLEGE CONTACT
Phone: +91-4259-200-300
Location: Coimbatore
Email: sece@sece.ac.in

© Sri Eshwar Engineering College. All Rights Reserved.

""").strip()
with open(file_path,"w",encoding="utf-8")as f:
  f.write(content)
print(f"Created Successfully!")
# Out:
# Created Successfully!

# %%
# !pip uninstall -y transformers sentence-transformers --q
# !pip install transformers==4.45.2 --q
# !pip install sentence-transformers==3.1.1  --q
print("installation Successfull!")
# Out:
# installation Successfull!

# %%
import os
from llama_index.llms.groq import Groq
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding


os.environ["GROQ_API_KEY"]=""

llm=Groq(model="llama-3.1-8b-instant")

embed_model=HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")

file_path="data/AIDS_Department.txt"

documents=SimpleDirectoryReader(input_files=[file_path]).load_data()

index=VectorStoreIndex.from_documents(documents,embed_model=embed_model)

query_engine=index.as_query_engine(llm=llm)

response= query_engine.query("Summarize the staff details in bullet points")
print("\n Document Summary:\n")
print(response)
# Out:
#  Document Summary:
#
# • The department has a Head of Department, Dr. G. Sathish Kumar, who is an Associate Professor.
# • The department also has an Associate Professor & HoD, Dr. M. Mohammed Mustafa.
# • The department office is managed by Ms. P. Brindha, the Department Office Secretary.
# • The department has a total of 25 faculty members, including Dr. L. Raja, Dr. K. Mohaideen Abdul Kadhar, Dr. S. Sheeba Rani Gnanamalar, Dr. G. Shobana, Dr. A. Sivaramakrishnan, Dr. M. P. Geetha, Dr. M. Thenmozhi, Dr. M. Nivaashini, Dr. P. Dinesh Kumar, Dr. T. Kanimozhi, Dr. L. R. Sujithra, Dr. C. Rajeshkumar, Ms. P. Chitra, Ms. S. Gowri, Ms. E. Anitha, Ms. S. Rajalakshmi, Ms. K. Parvathy, Ms. M. Sowmiya, Ms. S. Sowmiya, Mr. S. Sridharan, Ms. A. Soundarya, Ms. V. Sangavi, Ms. R. Geetha Rajakumari, Mr. R. Divakar, Ms. G. Durga Devi, Ms. N. Pooranam, Mr. S. Sam Peter, Ms. K. Parimalam, Ms. C. Saranya, Ms. D. Hema Malini, Ms. P. Anusha Devi, Ms. S. V. Uma, and Mr. Alaksandar Jesus Gene.

# %%
# !pip install docx2txt -q
import os
from llama_index.llms.groq import Groq
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding


os.environ["GROQ_API_KEY"]=""

llm=Groq(model="llama-3.1-8b-instant")

embed_model=HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")

file_path="data/"

documents=SimpleDirectoryReader(input_dir=file_path).load_data()

index=VectorStoreIndex.from_documents(documents,embed_model=embed_model)

query_engine=index.as_query_engine(llm=llm)

response= query_engine.query("""1)Summarize the staff details in AIDS department in bullet points
2)summarize the story as bullet point and give """)
print("\n Document Summary:\n")
print(response)
# Out:
#  Document Summary:
#
# 1. Staff details in AIDS department:
# - C. Rajeshkumar
# - Ms. P. Chitra
# - Ms. S. Gowri
# - Ms. E. Anitha
# - Ms. S. Rajalakshmi
# - Ms. K. Parvathy
# - Ms. M. Sowmiya
# - Ms. S. Sowmiya
# - Mr. S. Sridharan
# - Ms. A. Soundarya
# - Ms. V. Sangavi
# - Ms. R. Geetha Rajakumari
# - Mr. R. Divakar
# - Ms. G. Durga Devi
# - Ms. N. Pooranam
# - Mr. S. Sam Peter
# - Ms. K. Parimalam
# - Ms. C. Saranya
# - Ms. D. Hema Malini
# - Ms. P. Anusha Devi
# - Ms. S. V. Uma
# - Mr. Alaksandar Jesus Gene
#
# 2. Story summary:
# - A shape forms in a mirror's reflection, and a figure emerges from the darkness.
# - The entity in the mirror has a strange appearance and grins unnaturally.
# - It presses its fingers against the glass and causes a scratching sound in the protagonist's head.
# - The entity disappears, and the protagonist sees his own reflection in the mirror, screaming and begging to be let out.
# ...

# %%
from sentence_transformers import SentenceTransformer
model=SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded successfully")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Model loaded successfully

# %%
sentence="ETL is used to clean and transform data"
embedding=model.encode(sentence)

print(f"Input sentence:'{sentence}'")
print()
print(f"Embedding type:{type(embedding)}")
print(f"Embedding shape:{embedding.shape}")
print(f"First 10 numbers:{embedding[:10].round(4)}")
print(f"Min value:{embedding.min():.4f}")
print(f"Max value:{embedding.max():.4f}")
# Out:
# Input sentence:'ETL is used to clean and transform data'
#
# Embedding type:<class 'numpy.ndarray'>
# Embedding shape:(384,)
# First 10 numbers:[-0.0784  0.0541  0.0224 -0.0389  0.0221 -0.0904  0.0007 -0.0152  0.0733
#   0.0362]
# Min value:-0.1381
# Max value:0.1815

# %%
sentences=["ETL is used to clean and transform data",
    "Data transformation is a key pipeline step",
    "The sky is blue and the clouds are white"
]
embedding=model.encode(sentences)

print(f"Number of  sentence:{len(sentences)}")
print(f"Embedding shape:{embedding.shape}")
print()
print(f"Each row is one sentence's embedding:")
print(f"Min value:{embedding.min():.4f}")
print(f"Max value:{embedding.max():.4f}")
# Out:
# Number of  sentence:3
# Embedding shape:(3, 384)
#
# Each row is one sentence's embedding:
# Min value:-0.1685
# Max value:0.1815

# %%
import numpy as np
def cosine_similarity(vec_a,vec_b):
  dot_product=np.dot(vec_a,vec_b)

  norm_a=np.linalg.norm(vec_a)
  norm_b=np.linalg.norm(vec_b)

  return dot_product/(norm_a*norm_b)

sim_01=cosine_similarity(embedding[0],embedding[1])
sim_02=cosine_similarity(embedding[0],embedding[2])
sim_03=cosine_similarity(embedding[1],embedding[2])

print(f"Similarity (0 vs 1):{sim_01:.4f} ")
print(f"Similarity (0 vs 2):{sim_02:.4f} ")
print(f"Similarity (1 vs 2):{sim_03:.4f} ")
# Out:
# Similarity (0 vs 1):0.4357
# Similarity (0 vs 2):-0.0170
# Similarity (1 vs 2):0.0516
